# %% [markdown]
# <a href="https://colab.research.google.com/github/mdwai/JAVA-BOOK/blob/master/Regression%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Given data
x = np.array([1, 2, 2, 3]).reshape(-1, 1)
y = np.array([1, 2, 3, 6])

# Create and train regression model
model = LinearRegression()
model.fit(x, y)

# Predictions
y_pred = model.predict(x)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y, y_pred))

# Calculate R-squared
r2 = r2_score(y, y_pred)

# Plot the graph
plt.scatter(x, y)
plt.plot(x, y_pred)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Regression Graph")
plt.show()

# Print results
print("Predicted values:", y_pred)
print("RMSE:", rmse)
print("R-squared:", r2)
# Out:
# Predicted values: [0.5 3.  3.  5.5]
# RMSE: 0.6123724356957945
# R-squared: 0.8928571428571429
